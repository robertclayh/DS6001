# %%
x = [2, 5, 4, 7, 3]
w = [0.8, 1.2, 0.65, 1.45, 0.3]

weighted_average = sum(x_i * w_i for x_i, w_i in zip(x, w)) / sum(w)
print(weighted_average)  # Output should be approximately 4.83
# Out:
# 4.829545454545454
